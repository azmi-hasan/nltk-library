# %%
import nltk

# %%
with open('Desktop/brown_corpus_ca10.txt','r') as myfile:
    data=myfile.read().replace('\n','')

# %%
data2=data.replace("/","")

# %%
for i,line in enumerate(data2.split('\n')):
    if i>10:
        break
    print(str(i) + ':\t'+ line)
# Out:
# 0:	The university culture developed differently in northern Europe than it did in the south, although the northern (primarily Germany, France and Great Britain) and southern universities (primarily Italy) did have many elements in common. Latin was the language of the university, used for all texts, lectures, disputations and examinations. Professors lectured on the books of Aristotle for logic, natural philosophy, and metaphysics; while Hippocrates, Galen, and Avicenna were used for medicine. Outside of these commonalities, great differences separated north and south, primarily in subject matter. Italian universities focused on law and medicine, while the northern universities focused on the arts and theology. There were distinct differences in the quality of instruction in these areas which were congruent with their focus, so scholars would travel north or south based on their interests and means. There was also a difference in the types of degrees awarded at these universities. English, French and German universities usually awarded bachelor's degrees, with the exception of degrees in theology, for which the doctorate was more common. Italian universities awarded primarily doctorates. The distinction can be attributed to the intent of the degree holder after graduation â€“ in the north the focus tended to be on acquiring teaching positions, while in the south students often went on to professional positions.

# %%
from nltk import sent_tokenize,word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ['The university culture developed differently in northern Europe than it did in the south, although the northern (primarily Germany, France and Great Britain) and southern universities (primarily Italy) did have many elements in common.',
#  'Latin was the language of the university, used for all texts, lectures, disputations and examinations.',
#  'Professors lectured on the books of Aristotle for logic, natural philosophy, and metaphysics; while Hippocrates, Galen, and Avicenna were used for medicine.',
#  'Outside of these commonalities, great differences separated north and south, primarily in subject matter.',
#  'Italian universities focused on law and medicine, while the northern universities focused on the arts and theology.',
#  'There were distinct differences in the quality of instruction in these areas which were congruent with their focus, so scholars would travel north or south based on their interests and means.',
#  'There was also a difference in the types of degrees awarded at these universities.',
#  "English, French and German universities usually awarded bachelor's degrees, with the exception of degrees in theology, for which the doctorate was more common.",
#  'Italian universities awarded primarily doctorates.',
#  'The distinction can be attributed to the intent of the degree holder after graduation â€“ in the north the focus tended to be on acquiring teaching positions, while in the south students often went on to professional positions.']

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['The', 'university', 'culture', 'developed', 'differently', 'in', 'northern', 'Europe', 'than', 'it', 'did', 'in', 'the', 'south', ',', 'although', 'the', 'northern', '(', 'primarily', 'Germany', ',', 'France', 'and', 'Great', 'Britain', ')', 'and', 'southern', 'universities', '(', 'primarily', 'Italy', ')', 'did', 'have', 'many', 'elements', 'in', 'common', '.']
# ['Latin', 'was', 'the', 'language', 'of', 'the', 'university', ',', 'used', 'for', 'all', 'texts', ',', 'lectures', ',', 'disputations', 'and', 'examinations', '.']
# ['Professors', 'lectured', 'on', 'the', 'books', 'of', 'Aristotle', 'for', 'logic', ',', 'natural', 'philosophy', ',', 'and', 'metaphysics', ';', 'while', 'Hippocrates', ',', 'Galen', ',', 'and', 'Avicenna', 'were', 'used', 'for', 'medicine', '.']
# ['Outside', 'of', 'these', 'commonalities', ',', 'great', 'differences', 'separated', 'north', 'and', 'south', ',', 'primarily', 'in', 'subject', 'matter', '.']
# ['Italian', 'universities', 'focused', 'on', 'law', 'and', 'medicine', ',', 'while', 'the', 'northern', 'universities', 'focused', 'on', 'the', 'arts', 'and', 'theology', '.']
# ['There', 'were', 'distinct', 'differences', 'in', 'the', 'quality', 'of', 'instruction', 'in', 'these', 'areas', 'which', 'were', 'congruent', 'with', 'their', 'focus', ',', 'so', 'scholars', 'would', 'travel', 'north', 'or', 'south', 'based', 'on', 'their', 'interests', 'and', 'means', '.']
# ['There', 'was', 'also', 'a', 'difference', 'in', 'the', 'types', 'of', 'degrees', 'awarded', 'at', 'these', 'universities', '.']
# ['English', ',', 'French', 'and', 'German', 'universities', 'usually', 'awarded', 'bachelor', "'s", 'degrees', ',', 'with', 'the', 'exception', 'of', 'degrees', 'in', 'theology', ',', 'for', 'which', 'the', 'doctorate', 'was', 'more', 'common', '.']
# ['Italian', 'universities', 'awarded', 'primarily', 'doctorates', '.']
# ['The', 'distinction', 'can', 'be', 'attributed', 'to', 'the', 'intent', 'of', 'the', 'degree', 'holder', 'after', 'graduation', 'â€', '“', 'in', 'the', 'north', 'the', 'focus', 'tended', 'to', 'be', 'on', 'acquiring', 'teaching', 'positions', ',', 'while', 'in', 'the', 'south', 'students', 'often', 'went', 'on', 'to', 'professional', 'positions', '.']

# %%
from nltk.corpus import stopwords
stopwords_en=stopwords.words('english')

# %%
single_tokenized_lowered=list(map(str.lower,word_tokenize(data2)))
print(single_tokenized_lowered)
# Out:
# ['the', 'university', 'culture', 'developed', 'differently', 'in', 'northern', 'europe', 'than', 'it', 'did', 'in', 'the', 'south', ',', 'although', 'the', 'northern', '(', 'primarily', 'germany', ',', 'france', 'and', 'great', 'britain', ')', 'and', 'southern', 'universities', '(', 'primarily', 'italy', ')', 'did', 'have', 'many', 'elements', 'in', 'common', '.', 'latin', 'was', 'the', 'language', 'of', 'the', 'university', ',', 'used', 'for', 'all', 'texts', ',', 'lectures', ',', 'disputations', 'and', 'examinations', '.', 'professors', 'lectured', 'on', 'the', 'books', 'of', 'aristotle', 'for', 'logic', ',', 'natural', 'philosophy', ',', 'and', 'metaphysics', ';', 'while', 'hippocrates', ',', 'galen', ',', 'and', 'avicenna', 'were', 'used', 'for', 'medicine', '.', 'outside', 'of', 'these', 'commonalities', ',', 'great', 'differences', 'separated', 'north', 'and', 'south', ',', 'primarily', 'in', 'subject', 'matter', '.', 'italian', 'universities', 'focused', 'on', 'law', 'and', 'medicine', ',', 'while', 'the', 'northern', 'universities', 'focused', 'on', 'the', 'arts', 'and', 'theology', '.', 'there', 'were', 'distinct', 'differences', 'in', 'the', 'quality', 'of', 'instruction', 'in', 'these', 'areas', 'which', 'were', 'congruent', 'with', 'their', 'focus', ',', 'so', 'scholars', 'would', 'travel', 'north', 'or', 'south', 'based', 'on', 'their', 'interests', 'and', 'means', '.', 'there', 'was', 'also', 'a', 'difference', 'in', 'the', 'types', 'of', 'degrees', 'awarded', 'at', 'these', 'universities', '.', 'english', ',', 'french', 'and', 'german', 'universities', 'usually', 'awarded', 'bachelor', "'s", 'degrees', ',', 'with', 'the', 'exception', 'of', 'degrees', 'in', 'theology', ',', 'for', 'which', 'the', 'doctorate', 'was', 'more', 'common', '.', 'italian', 'universities', 'awarded', 'primarily', 'doctorates', '.', 'the', 'distinction', 'can', 'be', 'attributed', 'to', 'the', 'intent', 'of', 'the', 'degree', 'holder', 'after', 'graduation', 'â€', '“', 'in', 'the', 'north', 'the', 'focus', 'tended', 'to', 'be', 'on', 'acquiring', 'teaching', 'positions', ',', 'while', 'in', 'the', 'south', 'students', 'often', 'went', 'on', 'to', 'professional', 'positions', '.']

# %%
stopwords_en=set(stopwords.words('english'))
print([word for word in single_tokenized_lowered if word not in stopwords_en])
# Out:
# ['university', 'culture', 'developed', 'differently', 'northern', 'europe', 'south', ',', 'although', 'northern', '(', 'primarily', 'germany', ',', 'france', 'great', 'britain', ')', 'southern', 'universities', '(', 'primarily', 'italy', ')', 'many', 'elements', 'common', '.', 'latin', 'language', 'university', ',', 'used', 'texts', ',', 'lectures', ',', 'disputations', 'examinations', '.', 'professors', 'lectured', 'books', 'aristotle', 'logic', ',', 'natural', 'philosophy', ',', 'metaphysics', ';', 'hippocrates', ',', 'galen', ',', 'avicenna', 'used', 'medicine', '.', 'outside', 'commonalities', ',', 'great', 'differences', 'separated', 'north', 'south', ',', 'primarily', 'subject', 'matter', '.', 'italian', 'universities', 'focused', 'law', 'medicine', ',', 'northern', 'universities', 'focused', 'arts', 'theology', '.', 'distinct', 'differences', 'quality', 'instruction', 'areas', 'congruent', 'focus', ',', 'scholars', 'would', 'travel', 'north', 'south', 'based', 'interests', 'means', '.', 'also', 'difference', 'types', 'degrees', 'awarded', 'universities', '.', 'english', ',', 'french', 'german', 'universities', 'usually', 'awarded', 'bachelor', "'s", 'degrees', ',', 'exception', 'degrees', 'theology', ',', 'doctorate', 'common', '.', 'italian', 'universities', 'awarded', 'primarily', 'doctorates', '.', 'distinction', 'attributed', 'intent', 'degree', 'holder', 'graduation', 'â€', '“', 'north', 'focus', 'tended', 'acquiring', 'teaching', 'positions', ',', 'south', 'students', 'often', 'went', 'professional', 'positions', '.']

# %%
from string import punctuation
print('From string.punctuation:',type(punctuation),punctuation)
# Out:
# From string.punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en_withpunct=stopwords_en.union(set(punctuation))
print(stopwords_en_withpunct)
# Out:
# {'aren', 'our', 'when', "you'd", "mightn't", 'any', "mustn't", 'shan', 'is', 'before', ']', 'more', 'doing', 'can', 'did', '}', "haven't", '-', "weren't", 'again', 'she', "didn't", 'those', 'until', 'himself', "you've", 'of', 'about', 'down', 'after', 'who', 'over', 'then', 'nor', 've', 'themselves', ':', '@', 'in', ',', 'for', 'there', 'but', "isn't", '"', 're', 'once', 'ours', 'as', 'against', '^', '+', 's', 'couldn', 'd', 'myself', 'that', 'very', 'up', '\\', 'from', 'have', 'by', 'other', '.', 'are', ';', 'a', "shan't", 'am', 'theirs', 'under', '(', 'don', '>', 'mightn', 'ain', 'through', "'", 'her', 'being', "you're", 'which', '[', '_', "won't", 'wouldn', 'off', 'to', "hadn't", 'few', 'you', 'some', '&', '{', '%', 'been', 'had', 'having', 'your', 'out', 'these', 'most', 'why', 'does', 'ourselves', 'while', 'an', '|', 'just', 'do', 'this', 'same', 'won', 'll', '<', '$', 'be', "wouldn't", 'its', 'yourselves', 'because', 'yourself', '*', "you'll", 'was', 'whom', 'above', "it's", 'at', '#', 'were', 'their', 'or', "that'll", 'no', 'ma', "needn't", 'my', 'me', 'all', 'too', 'him', 'not', 'they', 'how', 'needn', "hasn't", 'his', 'further', 'wasn', 'has', 'only', 'them', 'both', 'yours', 'if', '/', 'haven', 'with', "she's", 'hers', '~', 'where', 'he', 'itself', "couldn't", 'doesn', 'weren', 'mustn', 'it', 'on', 'own', "should've", "doesn't", '!', 'such', 'than', 'between', 'into', 'o', "shouldn't", 'hasn', 'isn', 'each', "wasn't", 'here', "don't", 'herself', 'so', 'i', '?', 'm', 'will', 'hadn', 'should', 'didn', 'shouldn', 'below', 'y', '`', 't', 'the', 'during', ')', 'we', 'and', 'what', "aren't", 'now', '='}

# %%
print([word for word in single_tokenized_lowered if word not in stopwords_en_withpunct])
# Out:
# ['university', 'culture', 'developed', 'differently', 'northern', 'europe', 'south', 'although', 'northern', 'primarily', 'germany', 'france', 'great', 'britain', 'southern', 'universities', 'primarily', 'italy', 'many', 'elements', 'common', 'latin', 'language', 'university', 'used', 'texts', 'lectures', 'disputations', 'examinations', 'professors', 'lectured', 'books', 'aristotle', 'logic', 'natural', 'philosophy', 'metaphysics', 'hippocrates', 'galen', 'avicenna', 'used', 'medicine', 'outside', 'commonalities', 'great', 'differences', 'separated', 'north', 'south', 'primarily', 'subject', 'matter', 'italian', 'universities', 'focused', 'law', 'medicine', 'northern', 'universities', 'focused', 'arts', 'theology', 'distinct', 'differences', 'quality', 'instruction', 'areas', 'congruent', 'focus', 'scholars', 'would', 'travel', 'north', 'south', 'based', 'interests', 'means', 'also', 'difference', 'types', 'degrees', 'awarded', 'universities', 'english', 'french', 'german', 'universities', 'usually', 'awarded', 'bachelor', "'s", 'degrees', 'exception', 'degrees', 'theology', 'doctorate', 'common', 'italian', 'universities', 'awarded', 'primarily', 'doctorates', 'distinction', 'attributed', 'intent', 'degree', 'holder', 'graduation', 'â€', '“', 'north', 'focus', 'tended', 'acquiring', 'teaching', 'positions', 'south', 'students', 'often', 'went', 'professional', 'positions']

# %%
from nltk.stem import PorterStemmer
porter=PorterStemmer()

for word in single_tokenized_lowered:
    print(porter.stem(word))
# Out:
# the
# univers
# cultur
# develop
# differ
# in
# northern
# europ
# than
# it
# did
# in
# the
# south
# ,
# although
# the
# northern
# (
# primarili
# germani
# ,
# franc
# and
# great
# britain
# )
# and
# southern
# univers
# (
# primarili
# itali
# )
# did
# have
# mani
# element
# in
# common
# .
# latin
# wa
# the
# languag
# of
# the
# univers
# ,
# use
# for
# all
# text
# ,
# lectur
# ,
# disput
# and
# examin
# .
# professor
# lectur
# on
# the
# book
# of
# aristotl
# for
# logic
# ,
# natur
# philosophi
# ,
# and
# metaphys
# ;
# while
# hippocr
# ,
# galen
# ,
# and
# avicenna
# were
# use
# for
# medicin
# .
# outsid
# of
# these
# common
# ,
# great
# differ
# separ
# north
# and
# south
# ,
# primarili
# in
# subject
# matter
# .
# italian
# univers
# focus
# on
# law
# and
# medicin
# ,
# while
# the
# northern
# univers
# focus
# on
# the
# art
# and
# theolog
# .
# there
# were
# distinct
# differ
# in
# the
# qualiti
# of
# instruct
# in
# these
# area
# which
# were
# congruent
# with
# their
# focu
# ,
# so
# scholar
# would
# travel
# north
# or
# south
# base
# on
# their
# interest
# and
# mean
# .
# there
# wa
# also
# a
# differ
# in
# the
# type
# of
# degre
# award
# at
# these
# univers
# .
# english
# ,
# french
# and
# german
# univers
# usual
# award
# bachelor
# 's
# degre
# ,
# with
# the
# except
# of
# degre
# in
# theolog
# ,
# for
# which
# the
# doctor
# wa
# more
# common
# .
# italian
# univers
# award
# primarili
# doctor
# .
# the
# distinct
# can
# be
# attribut
# to
# the
# intent
# of
# the
# degre
# holder
# after
# graduat
# â€
# “
# in
# the
# north
# the
# focu
# tend
# to
# be
# on
# acquir
# teach
# posit
# ,
# while
# in
# the
# south
# student
# often
# went
# on
# to
# profession
# posit
# .

# %%
from nltk.stem import WordNetLemmatizer
wn1=WordNetLemmatizer()

# %%
for word in single_tokenized_lowered:
    print(wn1.lemmatize(word))
# Out:
# the
# university
# culture
# developed
# differently
# in
# northern
# europe
# than
# it
# did
# in
# the
# south
# ,
# although
# the
# northern
# (
# primarily
# germany
# ,
# france
# and
# great
# britain
# )
# and
# southern
# university
# (
# primarily
# italy
# )
# did
# have
# many
# element
# in
# common
# .
# latin
# wa
# the
# language
# of
# the
# university
# ,
# used
# for
# all
# text
# ,
# lecture
# ,
# disputation
# and
# examination
# .
# professor
# lectured
# on
# the
# book
# of
# aristotle
# for
# logic
# ,
# natural
# philosophy
# ,
# and
# metaphysics
# ;
# while
# hippocrates
# ,
# galen
# ,
# and
# avicenna
# were
# used
# for
# medicine
# .
# outside
# of
# these
# commonality
# ,
# great
# difference
# separated
# north
# and
# south
# ,
# primarily
# in
# subject
# matter
# .
# italian
# university
# focused
# on
# law
# and
# medicine
# ,
# while
# the
# northern
# university
# focused
# on
# the
# art
# and
# theology
# .
# there
# were
# distinct
# difference
# in
# the
# quality
# of
# instruction
# in
# these
# area
# which
# were
# congruent
# with
# their
# focus
# ,
# so
# scholar
# would
# travel
# north
# or
# south
# based
# on
# their
# interest
# and
# mean
# .
# there
# wa
# also
# a
# difference
# in
# the
# type
# of
# degree
# awarded
# at
# these
# university
# .
# english
# ,
# french
# and
# german
# university
# usually
# awarded
# bachelor
# 's
# degree
# ,
# with
# the
# exception
# of
# degree
# in
# theology
# ,
# for
# which
# the
# doctorate
# wa
# more
# common
# .
# italian
# university
# awarded
# primarily
# doctorate
# .
# the
# distinction
# can
# be
# attributed
# to
# the
# intent
# of
# the
# degree
# holder
# after
# graduation
# â€
# “
# in
# the
# north
# the
# focus
# tended
# to
# be
# on
# acquiring
# teaching
# position
# ,
# while
# in
# the
# south
# student
# often
# went
# on
# to
# professional
# position
# .

# %%
stop_words=set(stopwords.words('english'))
tokenized=sent_tokenize(data2)
for i in tokenized:
    wordslist=nltk.word_tokenize(i)
    wordslist=[w for w in wordslist if not w in stop_words]
    tagged=nltk.pos_tag(wordslist)
    
    print(tagged)
# Out:
# [('The', 'DT'), ('university', 'NN'), ('culture', 'NN'), ('developed', 'VBD'), ('differently', 'RB'), ('northern', 'JJ'), ('Europe', 'NNP'), ('south', 'NN'), (',', ','), ('although', 'IN'), ('northern', 'JJ'), ('(', '('), ('primarily', 'RB'), ('Germany', 'NNP'), (',', ','), ('France', 'NNP'), ('Great', 'NNP'), ('Britain', 'NNP'), (')', ')'), ('southern', 'JJ'), ('universities', 'NNS'), ('(', '('), ('primarily', 'RB'), ('Italy', 'NNP'), (')', ')'), ('many', 'JJ'), ('elements', 'NNS'), ('common', 'JJ'), ('.', '.')]
# [('Latin', 'JJ'), ('language', 'NN'), ('university', 'NN'), (',', ','), ('used', 'VBD'), ('texts', 'NN'), (',', ','), ('lectures', 'VBZ'), (',', ','), ('disputations', 'NNS'), ('examinations', 'NNS'), ('.', '.')]
# [('Professors', 'NNS'), ('lectured', 'VBD'), ('books', 'NNS'), ('Aristotle', 'NNP'), ('logic', 'NN'), (',', ','), ('natural', 'JJ'), ('philosophy', 'NN'), (',', ','), ('metaphysics', 'NNS'), (';', ':'), ('Hippocrates', 'NNP'), (',', ','), ('Galen', 'NNP'), (',', ','), ('Avicenna', 'NNP'), ('used', 'VBD'), ('medicine', 'NN'), ('.', '.')]
# [('Outside', 'JJ'), ('commonalities', 'NNS'), (',', ','), ('great', 'JJ'), ('differences', 'NNS'), ('separated', 'VBD'), ('north', 'JJ'), ('south', 'RB'), (',', ','), ('primarily', 'RB'), ('subject', 'JJ'), ('matter', 'NN'), ('.', '.')]
# [('Italian', 'JJ'), ('universities', 'NNS'), ('focused', 'VBD'), ('law', 'NN'), ('medicine', 'NN'), (',', ','), ('northern', 'JJ'), ('universities', 'NNS'), ('focused', 'VBD'), ('arts', 'NNS'), ('theology', 'NN'), ('.', '.')]
# [('There', 'EX'), ('distinct', 'JJ'), ('differences', 'NNS'), ('quality', 'NN'), ('instruction', 'NN'), ('areas', 'NNS'), ('congruent', 'JJ'), ('focus', 'NN'), (',', ','), ('scholars', 'NNS'), ('would', 'MD'), ('travel', 'VB'), ('north', 'RB'), ('south', 'RB'), ('based', 'VBN'), ('interests', 'NNS'), ('means', 'NNS'), ('.', '.')]
# [('There', 'EX'), ('also', 'RB'), ('difference', 'NN'), ('types', 'NNS'), ('degrees', 'NNS'), ('awarded', 'VBD'), ('universities', 'NNS'), ('.', '.')]
# [('English', 'JJ'), (',', ','), ('French', 'JJ'), ('German', 'JJ'), ('universities', 'NNS'), ('usually', 'RB'), ('awarded', 'VBD'), ('bachelor', 'NN'), ("'s", 'POS'), ('degrees', 'NNS'), (',', ','), ('exception', 'NN'), ('degrees', 'NNS'), ('theology', 'NN'), (',', ','), ('doctorate', 'JJ'), ('common', 'JJ'), ('.', '.')]
# [('Italian', 'JJ'), ('universities', 'NNS'), ('awarded', 'VBD'), ('primarily', 'RB'), ('doctorates', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('distinction', 'NN'), ('attributed', 'VBD'), ('intent', 'JJ'), ('degree', 'NN'), ('holder', 'NN'), ('graduation', 'NN'), ('â€', 'NNP'), ('“', 'NNP'), ('north', 'JJ'), ('focus', 'NN'), ('tended', 'VBD'), ('acquiring', 'VBG'), ('teaching', 'VBG'), ('positions', 'NNS'), (',', ','), ('south', 'JJ'), ('students', 'NNS'), ('often', 'RB'), ('went', 'VBD'), ('professional', 'JJ'), ('positions', 'NNS'), ('.', '.')]

# %%
sentences=nltk.sent_tokenize(data2)
tokenized_sentences=[nltk.word_tokenize(sentence) for sentence in sentences]
tagged_sentences=[nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences=nltk.ne_chunk_sents(tagged_sentences,binary=True)

def extract_entity_names(t):
    entity_names=[]
    
    if hasattr(t,'label') and t.label:
        if t.label()=='NE':
            entity_names.append(''.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
                
    return entity_names
    
entity_names=[]
for tree in chunked_sentences:
    entity_names.extend(extract_entity_names(tree))
    

                
print(set(entity_names))
# Out:
# {'French', 'France', 'GreatBritain', 'Latin', 'Avicenna', 'Italy', 'German', 'Germany', 'Europe', 'Aristotle', 'English', 'Galen', 'Italian'}
